# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshitha9286/coding-challenge-solutions/blob/main/coding_chlng_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter a number: "))
for num in range(2, n + 1):
    count = 0
    for i in range(1, num + 1):
        if num % i == 0:
            count += 1
    if count == 2:
        print(num)
# Out:
# Enter a number: 25
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19
# 23
